# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

# %%
df = pd.read_csv('coursea_data.csv')

# %%
df[0:9]
# Out:
#    Unnamed: 0                                       course_title  \
# 0         134  (ISC)² Systems Security Certified Practitioner...
# 1         743  A Crash Course in Causality:  Inferring Causal...
# 2         874                     A Crash Course in Data Science
# 3         413                            A Law Student's Toolkit
# 4         635                A Life of Happiness and Fulfillment
# 5         661  ADHD: Everyday Strategies for Elementary Students
# 6          54                                    AI For Everyone
# 7         488                           AI For Medical Treatment
# 8          58                        AI Foundations for Everyone
#
#           course_organization course_Certificate_type  course_rating  \
# 0                      (ISC)²          SPECIALIZATION            4.7
# 1  University of Pennsylvania                  COURSE            4.7
# 2    Johns Hopkins University                  COURSE            4.5
# 3             Yale University                  COURSE            4.7
# 4   Indian School of Business                  COURSE            4.8
# 5       University at Buffalo                  COURSE            4.7
# 6             deeplearning.ai                  COURSE            4.8
# 7             deeplearning.ai                  COURSE            4.8
# 8                         IBM          SPECIALIZATION            4.7
#
#   course_difficulty course_students_enrolled
# 0          Beginner                     5.3k
# 1      Intermediate                      17k
# 2             Mixed                     130k
# 3             Mixed                      91k
# 4             Mixed                     320k
# 5          Beginner                      39k
# 6          Beginner                     350k
# 7      Intermediate                     2.4k
# 8          Beginner                      61k

# %%
df[:]
# Out:
#      Unnamed: 0                                       course_title  \
# 0           134  (ISC)² Systems Security Certified Practitioner...
# 1           743  A Crash Course in Causality:  Inferring Causal...
# 2           874                     A Crash Course in Data Science
# 3           413                            A Law Student's Toolkit
# 4           635                A Life of Happiness and Fulfillment
# 5           661  ADHD: Everyday Strategies for Elementary Students
# 6            54                                    AI For Everyone
# 7           488                           AI For Medical Treatment
# 8            58                        AI Foundations for Everyone
# 9           129                           AI for Medical Diagnosis
# 10          283                           AI for Medical Prognosis
# 11           35                                    AI for Medicine
# 12           43                                   AWS Fundamentals
# 13          631         AWS Fundamentals: Addressing Security Risk
# 14          861  AWS Fundamentals: Building Serverless Applicat...
# 15          281               AWS Fundamentals: Going Cloud-Native
# 16          828           AWS Fundamentals: Migrating to the Cloud
# 17          819                Aboriginal Worldviews and Education
# 18           63                          Academic English: Writing
# 19          142          Accelerated Computer Science Fundamentals
# 20          612                                    Access Controls
# 21          604                               Accounting Analytics
# 22          727                     Accounting for Decision Making
# 23           51        Achieving Personal and Professional Success
# 24          838  Actualización en el manejo del paciente con di...
# 25          330  Addiction Treatment: Clinical Skills for Healt...
# 26          247                        Advanced Business Analytics
# 27          157                     Advanced Data Science with IBM
# 28          103                          Advanced Machine Learning
# 29          324  Advanced Machine Learning with TensorFlow on G...
# ..          ...                                                ...
# 861         144                          What Is Contemporary Art?
# 862         829                         What future for education?
# 863         543                                What is Compliance?
# 864          88                              What is Data Science?
# 865         379                                    What is Social?
# 866         232  Wine Tasting: Sensory Techniques for Wine Anal...
# 867         787                           Wonders of Ancient Egypt
# 868         619  Write A Feature Length Screenplay For Film Or ...
# 869         213               Write Professional Emails in English
# 870         684                             Write Your First Novel
# 871          69                            Writing in the Sciences
# 872         359  e-Learning Ecologies: Innovative Approaches to...
# 873         779                     iOS App Development with Swift
# 874         858  ¿Qué hacen los buenos directivos? Prioridades ...
# 875         191  Étudier en France: French Intermediate course ...
# 876         607                                  Éxito Profesional
# 877         492                          Искусство ведения бизнеса
# 878         156            Искусство разработки на современном C++
# 879         722         Корпоративные финансы и стоимость компании
# 880         811             Математика и Python для анализа данных
# 881         132                  Машинное обучение и анализ данных
# 882         405                          Основы Digital Маркетинга
# 883         703                  Основы программирования на Python
# 884         841               Основы разработки на C++: белый пояс
# 885         889                                Погружение в Python
# 886         236                         Программирование на Python
# 887         883               Психолингвистика (Psycholinguistics)
# 888         545       Разработка интерфейсов: вёрстка и JavaScript
# 889         875                            Русский как иностранный
# 890         163      Финансовые инструменты для частного инвестора
#
#                                    course_organization  \
# 0                                               (ISC)²
# 1                           University of Pennsylvania
# 2                             Johns Hopkins University
# 3                                      Yale University
# 4                            Indian School of Business
# 5                                University at Buffalo
# 6                                      deeplearning.ai
# 7                                      deeplearning.ai
# 8                                                  IBM
# 9                                      deeplearning.ai
# 10                                     deeplearning.ai
# 11                                     deeplearning.ai
# 12                                 Amazon Web Services
# 13                                 Amazon Web Services
# 14                                 Amazon Web Services
# 15                                 Amazon Web Services
# 16                                 Amazon Web Services
# 17                               University of Toronto
# 18                    University of California, Irvine
# 19          University of Illinois at Urbana-Champaign
# 20                                              (ISC)²
# 21                          University of Pennsylvania
# 22                              University of Michigan
# 23                          University of Pennsylvania
# 24             Universidad Nacional Autónoma de México
# 25                                     Yale University
# 26                      University of Colorado Boulder
# 27                                                 IBM
# 28   National Research University Higher School of ...
# 29                                        Google Cloud
# ..                                                 ...
# 861                           The Museum of Modern Art
# 862                         UCL Institute of Education
# 863                         University of Pennsylvania
# 864                                                IBM
# 865                            Northwestern University
# 866                    University of California, Davis
# 867                         University of Pennsylvania
# 868                          Michigan State University
# 869                    Georgia Institute of Technology
# 870                          Michigan State University
# 871                                Stanford University
# 872         University of Illinois at Urbana-Champaign
# 873                              University of Toronto
# 874                               IESE Business School
# 875                                École Polytechnique
# 876                   University of California, Irvine
# 877                  Saint Petersburg State University
# 878                        E-Learning Development Fund
# 879  National Research University Higher School of ...
# 880                        E-Learning Development Fund
# 881                        E-Learning Development Fund
# 882  National Research University Higher School of ...
# 883  National Research University Higher School of ...
# 884                        E-Learning Development Fund
# 885         Moscow Institute of Physics and Technology
# 886                                      Mail.Ru Group
# 887                  Saint Petersburg State University
# 888                        E-Learning Development Fund
# 889                  Saint Petersburg State University
# 890  National Research University Higher School of ...
#
#     course_Certificate_type  course_rating course_difficulty  \
# 0            SPECIALIZATION            4.7          Beginner
# 1                    COURSE            4.7      Intermediate
# 2                    COURSE            4.5             Mixed
# 3                    COURSE            4.7             Mixed
# 4                    COURSE            4.8             Mixed
# 5                    COURSE            4.7          Beginner
# 6                    COURSE            4.8          Beginner
# 7                    COURSE            4.8      Intermediate
# 8            SPECIALIZATION            4.7          Beginner
# 9                    COURSE            4.7      Intermediate
# 10                   COURSE            4.6      Intermediate
# 11           SPECIALIZATION            4.7      Intermediate
# 12           SPECIALIZATION            4.6          Beginner
# 13                   COURSE            4.3          Beginner
# 14                   COURSE            4.7          Beginner
# 15                   COURSE            4.7          Beginner
# 16                   COURSE            4.5      Intermediate
# 17                   COURSE            4.7             Mixed
# 18           SPECIALIZATION            4.7          Beginner
# 19           SPECIALIZATION            4.7      Intermediate
# 20                   COURSE            4.6          Beginner
# 21                   COURSE            4.5             Mixed
# 22                   COURSE            4.8      Intermediate
# 23           SPECIALIZATION            4.7          Beginner
# 24                   COURSE            4.8             Mixed
# 25                   COURSE            4.8          Beginner
# 26           SPECIALIZATION            4.5      Intermediate
# 27           SPECIALIZATION            4.4          Advanced
# 28           SPECIALIZATION            4.5          Advanced
# 29           SPECIALIZATION            4.5          Advanced
# ..                      ...            ...               ...
# 861                  COURSE            4.7          Beginner
# 862                  COURSE            4.7             Mixed
# 863                  COURSE            4.8             Mixed
# 864                  COURSE            4.7          Beginner
# 865                  COURSE            4.6             Mixed
# 866                  COURSE            4.7          Beginner
# 867                  COURSE            4.8      Intermediate
# 868                  COURSE            4.9          Beginner
# 869                  COURSE            4.7             Mixed
# 870                  COURSE            4.4          Beginner
# 871                  COURSE            4.9          Beginner
# 872                  COURSE            4.5             Mixed
# 873          SPECIALIZATION            3.9      Intermediate
# 874                  COURSE            4.7          Beginner
# 875                  COURSE            4.8      Intermediate
# 876          SPECIALIZATION            4.5          Beginner
# 877          SPECIALIZATION            4.6          Beginner
# 878          SPECIALIZATION            4.9      Intermediate
# 879          SPECIALIZATION            4.5          Beginner
# 880                  COURSE            4.8          Beginner
# 881          SPECIALIZATION            4.7      Intermediate
# 882          SPECIALIZATION            4.5      Intermediate
# 883                  COURSE            4.6          Beginner
# 884                  COURSE            4.9      Intermediate
# 885                  COURSE            4.7      Intermediate
# 886          SPECIALIZATION            4.5      Intermediate
# 887                  COURSE            4.8             Mixed
# 888          SPECIALIZATION            4.5      Intermediate
# 889          SPECIALIZATION            4.6      Intermediate
# 890          SPECIALIZATION            4.7          Beginner
#
#     course_students_enrolled
# 0                       5.3k
# 1                        17k
# 2                       130k
# 3                        91k
# 4                       320k
# 5                        39k
# 6                       350k
# 7                       2.4k
# 8                        61k
# 9                        12k
# 10                        4k
# 11                       13k
# 12                      130k
# 13                       11k
# 14                       27k
# 15                      110k
# 16                       13k
# 17                      6.6k
# 18                      540k
# 19                       22k
# 20                      2.9k
# 21                       80k
# 22                      9.9k
# 23                      110k
# 24                       23k
# 25                      9.2k
# 26                       78k
# 27                      320k
# 28                      190k
# 29                       35k
# ..                       ...
# 861                     120k
# 862                      35k
# 863                     6.2k
# 864                     260k
# 865                      94k
# 866                      32k
# 867                      17k
# 868                      12k
# 869                     270k
# 870                      18k
# 871                     140k
# 872                      17k
# 873                      76k
# 874                      25k
# 875                     190k
# 876                      69k
# 877                      14k
# 878                      68k
# 879                      16k
# 880                      67k
# 881                      77k
# 882                      19k
# 883                      83k
# 884                      41k
# 885                      45k
# 886                      52k
# 887                      21k
# 888                      30k
# 889                     9.8k
# 890                      38k
#
# [891 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'course_title', 'course_organization',
#        'course_Certificate_type', 'course_rating', 'course_difficulty',
#        'course_students_enrolled'],
#       dtype='object')

# %%
df['course_students_enrolled']=df['course_students_enrolled'].str.replace('k', '*1000')

# %%
df['course_students_enrolled']=df['course_students_enrolled'].str.replace('m', '*1000000')

# %%
df['course_students_enrolled'] = df['course_students_enrolled'].map(lambda x: eval(x))

# %%
df['course_students_enrolled']
# Out:
# 0        5300.0
# 1       17000.0
# 2      130000.0
# 3       91000.0
# 4      320000.0
# 5       39000.0
# 6      350000.0
# 7        2400.0
# 8       61000.0
# 9       12000.0
# 10       4000.0
# 11      13000.0
# 12     130000.0
# 13      11000.0
# 14      27000.0
# 15     110000.0
# 16      13000.0
# 17       6600.0
# 18     540000.0
# 19      22000.0
# 20       2900.0
# 21      80000.0
# 22       9900.0
# 23     110000.0
# 24      23000.0
# 25       9200.0
# 26      78000.0
# 27     320000.0
# 28     190000.0
# 29      35000.0
#          ...
# 861    120000.0
# 862     35000.0
# 863      6200.0
# 864    260000.0
# 865     94000.0
# 866     32000.0
# 867     17000.0
# 868     12000.0
# 869    270000.0
# 870     18000.0
# 871    140000.0
# 872     17000.0
# 873     76000.0
# 874     25000.0
# 875    190000.0
# 876     69000.0
# 877     14000.0
# 878     68000.0
# 879     16000.0
# 880     67000.0
# 881     77000.0
# 882     19000.0
# 883     83000.0
# 884     41000.0
# 885     45000.0
# 886     52000.0
# 887     21000.0
# 888     30000.0
# 889      9800.0
# 890     38000.0
# Name: course_students_enrolled, Length: 891, dtype: float64

# %%
df.describe()
# Out:
#        Unnamed: 0  course_rating  course_students_enrolled
# count  891.000000     891.000000              8.910000e+02
# mean   445.000000       4.677329              9.055208e+04
# std    257.353842       0.162225              1.819365e+05
# min      0.000000       3.300000              1.500000e+03
# 25%    222.500000       4.600000              1.750000e+04
# 50%    445.000000       4.700000              4.200000e+04
# 75%    667.500000       4.800000              9.950000e+04
# max    890.000000       5.000000              3.200000e+06

# %%
f,ax=plt.subplots(1,2,figsize=(15,5))
colours = ["maroon", "navy", "gold"]
sns.countplot('course_Certificate_type',ax=ax[0],data=df,palette=colours)
ax[0].set_title('course Certificate type')
ax[0].set_ylabel('')
sns.countplot('course_difficulty',ax=ax[1],data=df,palette=colours)
ax[1].set_title('course difficulty')
ax[1].set_ylabel('')
plt.subplots_adjust(wspace=0.8)
plt.show()

# %%
fig=plt.figure(figsize=(10,6))

sns.countplot('course_Certificate_type',data=df,hue='course_rating' )
plt.tight_layout()
plt.show()

fig=plt.figure(figsize=(10,6))
sns.countplot('course_difficulty',data=df,hue='course_rating' )
plt.tight_layout()
plt.show()

# %%
ct=df.groupby(['course_title'])['course_title'].count()

co=df.groupby(['course_organization'])['course_organization'].count()

co=pd.DataFrame(co)
co=co.rename(columns={"course_organization": "Count"})
co=co.sort_values(by=['Count'], ascending=False)
co=co.reset_index()
co_top_10=co.head(10)
co_top_10
# Out:
#                           course_organization  Count
# 0                  University of Pennsylvania     59
# 1                      University of Michigan     41
# 2                                Google Cloud     34
# 3                             Duke University     28
# 4                    Johns Hopkins University     28
# 5            University of California, Irvine     27
# 6  University of Illinois at Urbana-Champaign     22
# 7                                         IBM     22
# 8             University of California, Davis     21
# 9              University of Colorado Boulder     19

# %%
    ct_enrolled=df.loc[:,['course_title', 'course_students_enrolled']]
    ct_enrolled=ct_enrolled.sort_values(by=['course_students_enrolled'], ascending=False)
    ct_enrolled_top10=ct_enrolled.head(10)
    ct_enrolled_top10
# Out:
#                                           course_title  \
# 564                                   Machine Learning
# 815                          The Science of Well-Being
# 688                               Python for Everybody
# 674  Programming for Everybody (Getting Started wit...
# 196                                       Data Science
# 129                                     Career Success
# 261                     English for Career Development
# 765  Successful Negotiation: Essential Strategies a...
# 199                  Data Science: Foundations using R
# 211                                      Deep Learning
#
#      course_students_enrolled
# 564                 3200000.0
# 815                 2500000.0
# 688                 1500000.0
# 674                 1300000.0
# 196                  830000.0
# 129                  790000.0
# 261                  760000.0
# 765                  750000.0
# 199                  740000.0
# 211                  690000.0

# %%
Causality=df["course_title"].str.contains("Causality",case=False).value_counts(ascending=True).to_frame()
Data_Science=df["course_title"].str.contains("Data Science",case=False).value_counts(ascending=True).to_frame()
Law=df["course_title"].str.contains("Law",case=False).value_counts(ascending=True).to_frame()
AI=df["course_title"].str.contains("AI",case=False).value_counts(ascending=True).to_frame()
AWS=df["course_title"].str.contains("AWS",case=False).value_counts(ascending=True).to_frame()
Statistics=df["course_title"].str.contains("Statistics",case=False).value_counts(ascending=True).to_frame()
Blockchain=df["course_title"].str.contains("Blockchain",case=False).value_counts(ascending=True).to_frame()
Big_Data=df["course_title"].str.contains("Big Data",case=False).value_counts(ascending=True).to_frame()
Programming=df["course_title"].str.contains("Programming",case=False).value_counts(ascending=True).to_frame()
python=df["course_title"].str.contains("python",case=False).value_counts(ascending=True).to_frame()
Data_Analysis=df["course_title"].str.contains("Data Analysis",case=False).value_counts(ascending=True).to_frame()
Data_Visualization=df["course_title"].str.contains("Data Visualization",case=False).value_counts(ascending=True).to_frame()
Health=df["course_title"].str.contains("Health",case=False).value_counts(ascending=True).to_frame()
English=df["course_title"].str.contains("English",case=False).value_counts(ascending=True).to_frame()
Excel=df["course_title"].str.contains("Excel",case=False).value_counts(ascending=True).to_frame()
Finance=df["course_title"].str.contains("Finance",case=False).value_counts(ascending=True).to_frame()
Web_Development=df["course_title"].str.contains("Web Development",case=False).value_counts(ascending=True).to_frame()
Cloud_Computing=df["course_title"].str.contains("Cloud Computing",case=False).value_counts(ascending=True).to_frame()
Psychology=df["course_title"].str.contains("Psychology",case=False).value_counts(ascending=True).to_frame()
Cyber_Security=df["course_title"].str.contains("Cyber Security",case=False).value_counts(ascending=True).to_frame()

result = pd.concat([Causality,Data_Science,Law,AI,AWS,Statistics,Blockchain,Big_Data,Programming,python,Data_Analysis,
                                        Data_Visualization,Health,English,Excel,Finance,Web_Development,Cloud_Computing,
                                        Psychology,Cyber_Security],axis=1).drop(index=0)
result_t=result.transpose()
result_t.columns=['count']
result_t.insert(0, "Names",["Causality","Data_Science","Law","AI","AWS","Statistics","Blockchain","Big_Data","Programming",
                                        "python","Data_Analysis","Data_Visualization","Health","English","Excel","Finance",
                                        "Web_Development","Cloud_Computing","Psychology","Cyber_Security"], True)
f,ax=plt.subplots(1,1,figsize=(25,7))
ax = sns.barplot(x="Names", y = "count", data = result_t)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45,horizontalalignment='right',size=15)
# Out:
# Text(0, 0.5, 'Counts')

# %%
df1=df['course_Certificate_type'].value_counts()
data=['COURSE','SPECIALIZATION','PROFESSIONAL CERTIFICATE'] 
explode = (0, 0.1, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')
fig1, ax1 = plt.subplots()
ax1.pie(df1, explode=explode, labels=data, autopct='%1.1f%%',shadow=True, startangle=90)
ax1.axis('equal')  
plt.show()

# %%
# Prepare Data
df1=df.head(100)
df2= df1.groupby('course_difficulty').size()
# Make the plot with pandas
df2.plot(kind='pie', subplots=True, figsize=(5, 5))
plt.title("Pie Chart of Various Category of Difficulty")
plt.ylabel("")
plt.show()

# %%
ax = df['course_Certificate_type'].value_counts().plot(kind='bar', figsize=(16,12),
                                        color="coral", fontsize=13);
ax.set_alpha(0.8)
ax.set_title("course_Certificate_type", fontsize=18)
ax.set_ylabel("Count", fontsize=18);


# create a list to collect the plt.patches data
totals = []

# find the values and append to list
for i in ax.patches:
    totals.append(i.get_height())

# set individual bar lables using above list
total = sum(totals)

# set individual bar lables using above list
for i in ax.patches:
    # get_x pulls left or right; get_height pushes up or down
    ax.text(i.get_x(), i.get_height()+.5, \
            str(round((i.get_height()/total)*100, 2))+'%', fontsize=15,
                color='dimgrey')

# %%
ax = df['course_rating'].value_counts().plot(kind='bar', figsize=(16,12),
                                        color="dodgerblue", fontsize=13);
ax.set_alpha(0.8)
ax.set_title("course_rating", fontsize=18)
ax.set_ylabel("Count", fontsize=18);

# create a list to collect the plt.patches data
totals = []

# find the values and append to list
for i in ax.patches:
    totals.append(i.get_height())

# set individual bar lables using above list
total = sum(totals)

# set individual bar lables using above list
for i in ax.patches:
    # get_x pulls left or right; get_height pushes up or down
    ax.text(i.get_x(), i.get_height()+.5, \
            str(round((i.get_height()/total)*100, 2))+'%', fontsize=15,
                color='dimgrey')

# %%
ax = df['course_difficulty'].value_counts().plot(kind='bar', figsize=(16,12),
                                        color="#97ed55", fontsize=13);
ax.set_alpha(0.8)
ax.set_title("course_difficulty", fontsize=18)
ax.set_ylabel("Count", fontsize=18);

# create a list to collect the plt.patches data
totals = []

# find the values and append to list
for i in ax.patches:
    totals.append(i.get_height())

# set individual bar lables using above list
total = sum(totals)

# set individual bar lables using above list
for i in ax.patches:
    # get_x pulls left or right; get_height pushes up or down
    ax.text(i.get_x(), i.get_height()+.5, \
            str(round((i.get_height()/total)*100, 2))+'%', fontsize=15,
                color='dimgrey')

# %%
ct=df.groupby(['course_title'])['course_title'].count()
ct
# Out:
# course_title
# (ISC)² Systems Security Certified Practitioner (SSCP)                                       1
# A Crash Course in Causality:  Inferring Causal Effects from Observational Data              1
# A Crash Course in Data Science                                                              1
# A Law Student's Toolkit                                                                     1
# A Life of Happiness and Fulfillment                                                         1
# ADHD: Everyday Strategies for Elementary Students                                           1
# AI For Everyone                                                                             1
# AI For Medical Treatment                                                                    1
# AI Foundations for Everyone                                                                 1
# AI for Medical Diagnosis                                                                    1
# AI for Medical Prognosis                                                                    1
# AI for Medicine                                                                             1
# AWS Fundamentals                                                                            1
# AWS Fundamentals: Addressing Security Risk                                                  1
# AWS Fundamentals: Building Serverless Applications                                          1
# AWS Fundamentals: Going Cloud-Native                                                        1
# AWS Fundamentals: Migrating to the Cloud                                                    1
# Aboriginal Worldviews and Education                                                         1
# Academic English: Writing                                                                   1
# Accelerated Computer Science Fundamentals                                                   1
# Access Controls                                                                             1
# Accounting Analytics                                                                        1
# Accounting for Decision Making                                                              1
# Achieving Personal and Professional Success                                                 1
# Actualización en el manejo del paciente con diabetes mellitus tipo 2                        1
# Addiction Treatment: Clinical Skills for Healthcare Providers                               1
# Advanced Business Analytics                                                                 1
# Advanced Data Science with IBM                                                              1
# Advanced Machine Learning                                                                   1
# Advanced Machine Learning with TensorFlow on Google Cloud Platform                          1
#                                                                                            ..
# What Is Contemporary Art?                                                                   1
# What future for education?                                                                  1
# What is Compliance?                                                                         1
# What is Data Science?                                                                       1
# What is Social?                                                                             1
# Wine Tasting: Sensory Techniques for Wine Analysis                                          1
# Wonders of Ancient Egypt                                                                    1
# Write A Feature Length Screenplay For Film Or Television                                    1
# Write Professional Emails in English                                                        1
# Write Your First Novel                                                                      1
# Writing in the Sciences                                                                     1
# e-Learning Ecologies: Innovative Approaches to Teaching and Learning for the Digital Age    1
# iOS App Development with Swift                                                              1
# ¿Qué hacen los buenos directivos? Prioridades de la Alta Dirección                          1
# Étudier en France: French Intermediate course B1-B2                                         1
# Éxito Profesional                                                                           1
# Искусство ведения бизнеса                                                                   1
# Искусство разработки на современном C++                                                     1
# Корпоративные финансы и стоимость компании                                                  1
# Математика и Python для анализа данных                                                      1
# Машинное обучение и анализ данных                                                           1
# Основы Digital Маркетинга                                                                   1
# Основы программирования на Python                                                           1
# Основы разработки на C++: белый пояс                                                        1
# Погружение в Python                                                                         1
# Программирование на Python                                                                  1
# Психолингвистика (Psycholinguistics)                                                        1
# Разработка интерфейсов: вёрстка и JavaScript                                                1
# Русский как иностранный                                                                     1
# Финансовые инструменты для частного инвестора                                               1
# Name: course_title, Length: 888, dtype: int64

# %%
co=df.groupby(['course_organization'])['course_organization'].count()
co
# Out:
# course_organization
# (ISC)²                                           3
# Amazon Web Services                              6
# American Institute of Business and Economics     1
# American Museum of Natural History               2
# Arizona State University                         7
# Atlassian                                        2
# Autodesk                                         4
# Automation Anywhere                              1
# BCG                                              1
# Berklee College of Music                        14
# Birkbeck, University of London                   1
# Bloomsbury Learning Exchange                     1
# California Institute of the Arts                 6
# Case Western Reserve University                  3
# Cisco                                            2
# Cloudera                                         1
# Columbia University                              7
# ConsenSys Academy                                1
# Copenhagen Business School                       5
# Crece con Google                                 1
# Duke University                                 28
# E-Learning Development Fund                      6
# EDHEC Business School                            3
# ESADE Business and Law School                    1
# ESCP Business School                             1
# ESSEC Business School                            8
# Eindhoven University of Technology               1
# Emory University                                 5
# Erasmus University Rotterdam                     5
# Fundação Instituto de Administração              1
#                                                 ..
# University of California, Santa Cruz             4
# University of Cape Town                          3
# University of Colorado Boulder                  19
# University of Colorado System                   13
# University of Copenhagen                         2
# University of Florida                            3
# University of Geneva                             6
# University of Illinois at Urbana-Champaign      22
# University of Lausanne                           1
# University of London                             3
# University of Maryland, College Park             6
# University of Michigan                          41
# University of Minnesota                         11
# University of New Mexico                         1
# University of Pennsylvania                      59
# University of Pittsburgh                         3
# University of Toronto                           11
# University of Virginia                          19
# University of Washington                         5
# Università Bocconi                               7
# VMware                                           1
# Vanderbilt University                            3
# Wesleyan University                              5
# West Virginia University                         2
# Yale University                                 17
# Yonsei University                                4
# deeplearning.ai                                 16
# École Polytechnique                              1
# École Polytechnique Fédérale de Lausanne         4
# École des Ponts ParisTech                        1
# Name: course_organization, Length: 154, dtype: int64

# %%
co=pd.DataFrame(co)

# %%
co=co.rename(columns={"course_organization": "Count"})

# %%
co=co.sort_values(by=['Count'], ascending=False)

# %%
co=co.sort_values(by=['Count'], ascending=False)

# %%
co=co.reset_index()

# %%
co_top_10=co.head(10)

# %%
co_top_10
# Out:
#                           course_organization  Count
# 0                  University of Pennsylvania     59
# 1                      University of Michigan     41
# 2                                Google Cloud     34
# 3                    Johns Hopkins University     28
# 4                             Duke University     28
# 5            University of California, Irvine     27
# 6  University of Illinois at Urbana-Champaign     22
# 7                                         IBM     22
# 8             University of California, Davis     21
# 9              University of Colorado Boulder     19

# %%
fig = plt.figure(figsize=(16, 12))
ax = fig.add_axes([0,0,1,1])
ax.bar(co_top_10['course_organization'], co_top_10['Count'])
plt.show()

# %%
ct_enrolled=df.loc[:,['course_title', 'course_students_enrolled']]
